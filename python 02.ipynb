# %% [markdown]
# <div align="center">
#
# <font color=0F5298 size=8>
# Python 02
#
# <font color= 6C3BAA size=6>
#  <br>
# set, Dictionary, list, tuple
# <br>
# <font color=GREEN size=5>
# HAKAN Fatemi (www.hooko.ir)
#
#
# ____

# %%
thislist = ["apple", 1, 10.1, 1]
print(thislist)
# Out:
# ['apple', 1, 10.1, 1]

# %%
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[1])
# Out:
# banana

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[:4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:])
# Out:
# ['cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

print(thislist[-4:-1])

# %% [markdown]
# ## List example

# %%
cities = ["Tehran", "Ahvaz", "Golestan"]
print("First city:", cities[0])
# Out:
# First city: Tehran

# %%
thislist = ["apple", "banana", "cherry"]
thislist[2] = "blackcurrant"
print(thislist)
# Out:
# ['apple', 'banana', 'blackcurrant']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
thislist = ["apple", "banana", "cherry"]

thislist.append("orange")

print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist =["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]

thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
thislist = ["apple", "banana", "cherry", "melon", "kiwi"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry', 'melon', 'kiwi']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist1 = ["orange", "mango", "kiwi"]

thislist1.sort()
print(thislist1)
# Out:
# ['kiwi', 'mango', 'orange']

# %%
thislist2 = ["orange", "ma", "kiwi", "pineapple", "banana"]
thislist2.sort(key= len)
print(thislist2)
# Out:
# ['ma', 'kiwi', 'orange', 'banana', 'pineapple']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key = str.lower)
print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
thislist = ["apple", "banana", "cherry"]

mylist = thislist.copy()

print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist1 = [100, 50, 65, 82, 23]
thislist1.sort()
print(thislist1)
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist2 = [100, 50, 65, 82, 23]
thislist2.sort(reverse = True)
print(thislist2)
# Out:
# [100, 82, 65, 50, 23]

# %%
list1 = [450, 500, 470, 600, 550]

average_rainfall = sum(list1) / len(list1)

print(average_rainfall)
# Out:
# 514.0

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple1 = ("apple",)
print(type(thistuple1))
# Out:
# <class 'tuple'>

# %%
thistuple2 = ("apple")
print(type(thistuple2))
# Out:
# <class 'str'>

# %%
thistuple = ("apple", "banana", "cherry")

print(thistuple[1], thistuple[-1])
# Out:
# banana cherry

# %%
thistuple = ("apple", "banana", "cherry")

print(thistuple[1], thistuple[-1])
# Out:
# banana cherry

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[:4])
print(thistuple[2:])
# Out:
# ('apple', 'banana', 'cherry', 'orange')
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
thistuple = ("apple", 1, "cherry", 10.1, "kiwi", False, True)
print(thistuple[-4:-1])
# Out:
# (10.1, 'kiwi', False)

# %%
x = ("apple", "banana", "cherry")
y = list(x)

y[1] = "kiwi"

x = tuple(y)
print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")

y = ("orange",)

thistuple += y
# thistuple = thistuple + y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)

y.remove("apple")

thistuple = tuple(y)
print(thistuple)
# Out:
# ('banana', 'cherry')

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")
(green, yellow, *red) = fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
thisdict = {
  "brand": ["Ford", "benz"],
  "model": ["Mustang", "c500"],
  "year": [1964, 2018]
  }

print(thisdict)
# Out:
# {'brand': ['Ford', 'benz'], 'model': ['Mustang', 'c500'], 'year': [1964, 2018]}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(thisdict["brand"])
# Out:
# Ford

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(type(thisdict))
x = thisdict.keys()
print(x)
# Out:
# <class 'dict'>
# dict_keys(['brand', 'model', 'year'])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()
print(x) #before the change
car["color"] = "white"
print(car)
print(x) #after the change
# Out:
# dict_keys(['brand', 'model', 'year'])
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'white'}
# dict_keys(['brand', 'model', 'year', 'color'])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}
x = car.values()
print(x) #before the change
car["year"] = 2020
print(x) #after the change
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_values(['Ford', 'Mustang', 2020])

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}


thisdict.update({"year": 2020})
print(thisdict) #after the change
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"color": "red"})
print(thisdict) #after the change
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

del thisdict
print(thisdict)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

thisdict.clear()
print(thisdict)
# Out:
# {}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = dict(thisdict)
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
child1 = {
  "name" : "Amir",
  "year" : 1994}

child2 = {
  "name" : "Aria",
  "year" : 2000}

child3 = {
  "name" : "Mina",
  "year" : 2003}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3}

print(myfamily["child2"]["name"])
# Out:
# Aria

# %% [markdown]
# ## set

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2.0}
print(thisset)
# Out:
# {True, 2.0, 'apple', 'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry", False, True, 0}
print(thisset)
# Out:
# {False, True, 'apple', 'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
print(len(thisset))
# Out:
# 3

# %%
myset = {"apple", "banana", "cherry"}
print(type(myset))
# Out:
# <class 'set'>

# %%
thisset = {"apple", "banana", "cherry"}

print("banana" not in thisset)
print("Cherry" not in thisset)
# Out:
# False
# True

# %%
thisset = {"apple", "banana", "cherry"}
thisset.add("orange")
print(thisset)
# Out:
# {'apple', 'orange', 'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}

tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)
print(thisset)
# Out:
# {'papaya', 'mango', 'pineapple', 'apple', 'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]
thisset.update(mylist)
print(thisset)
# Out:
# {'orange', 'cherry', 'kiwi', 'apple', 'banana'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.remove("banana")
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.discard("banana")
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}
thisset.clear()
print(thisset)
# Out:
# set()

# %%
thisset = {"apple", "banana", "cherry"}
del thisset
print(thisset)

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 'c', 'b', 'a'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}
myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {1, 2, 3, 'bananas', 'John', 'b', 'cherry', 'Elena', 'apple', 'c', 'a'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = set1 | set2
print(set3)
# Out:
# {1, 2, 3, 'c', 'b', 'a'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}
myset = set1 | set2 | set3 |set4
print(myset)
# Out:
# {1, 2, 3, 'bananas', 'John', 'b', 'cherry', 'Elena', 'apple', 'c', 'a'}

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}
set1.update(set2)
print(set1)
# Out:
# {1, 2, 3, 'c', 'b', 'a'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.difference(set2)
print(set3)
# Out:
# {'banana', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set2.difference(set1)
print(set3)
# Out:
# {'google', 'microsoft'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1 - set2
print(set3)
# Out:
# {'banana', 'cherry'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = { "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)
print(set3)
# Out:
# {'cherry', 'banana', 'microsoft'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1 ^ set2
print(set3)
# Out:
# {'microsoft', 'cherry', 'google', 'banana'}

# %% [markdown]
# ## Author
#
# Mahdi Fatemi (HAKAN)
#
# ## web
# www.hooko.ir
#
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2025-11-06 | 1.0  | HAKAN Fatemi  |  ... |
#
# ## <h3 align="center"> © HOOKO.IR Corporation. All rights reserved. <h3/>
